# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt('system1.csv', delimiter=',')

millis = data[:,0]
dist_raw = data[:,1]
dist_filtered = data[:,2]
water_height = data[:,3]
setpoint = data[:,4]
pid_val = data[:,5]

# %%
plt.figure(figsize=(20,12))
plt.title("Resposta")
plt.xlabel("Tempo (s)")
plt.ylabel("Altura de água (cm)")
plt.plot(millis/1000, water_height)

# %%
plt.figure(figsize=(20,12))
plt.plot(millis/1000, dist_raw)
plt.plot(millis/1000, dist_filtered)
